# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob

# %% [markdown]
# add Path of image-directory

# %%
pathImages = 'C:/Users/shadmehr/Downloads/Compressed/Subtracted images of CDD-CESM'

# %% [markdown]
# add path of manual excel file directory

# %%
pathManual = 'C:/Users/shadmehr/Downloads/Compressed/Radiology manual annotations.xlsx'
manualRadio = pd.read_excel(pathManual)

# %% [markdown]
# rename lable of manual file

# %%
manualRadio= manualRadio.rename(columns={'Pathology Classification/ Follow up':'classification'})

# %% [markdown]
# discard Type DM

# %%
manualRadio = manualRadio[manualRadio['Type']=='CESM']

# %%
manualRadio.head()
# Out:
#     Image_name  Patient_ID Side  Type  Age Breast density (ACR) BIRADS
# 1  P1_L_CM_MLO           1    L  CESM   46                    _      4  \
# 4   P2_R_CM_CC           2    R  CESM   31                    _      3
# 5  P2_R_CM_MLO           2    R  CESM   31                    _      3
# 8   P2_L_CM_CC           2    L  CESM   31                    _      2
# 9  P2_L_CM_MLO           2    L  CESM   31                    _      2
#
#                                    Findings View                        Tags
# 1        Heterogenous non mass enhancement   MLO        suspicious, non mass  \
# 4  Multiple homogenously enhancing  masses    CC  benign, masses, homogenous
# 5  Multiple homogenously enhancing  masses   MLO  benign, masses, homogenous
# 8                  Flap with no enhancement   CC                flap, benign
# 9                  Flap with no enhancement  MLO                flap, benign
#
#    Machine classification
# 1        1      Malignant
# 4        2         Benign
# 5        2         Benign
# 8        2         Benign
# 9        2         Benign

# %% [markdown]
# load Images

# %%
import os
images = os.listdir(pathImages)
loaded_images = []
#filename_txt = []
for filename in images:
    if filename.endswith('.jpg') or filename.endswith('.png'):
        image_list = plt.imread(os.path.join(pathImages, filename))
        loaded_images.append(image_list)
        #filename_txt.append(filename)

# %%
manualRadio = manualRadio.sort_values(by=['Image_name'])

# %%
manualRadio.head()
# Out:
#         Image_name  Patient_ID Side  Type  Age Breast density (ACR) BIRADS
# 556   P100_L_CM_CC         100    L  CESM   61                    _      2  \
# 557  P100_L_CM_MLO         100    L  CESM   61                    _      2
# 552   P100_R_CM_CC         100    R  CESM   61                    _      1
# 553  P100_R_CM_MLO         100    R  CESM   61                    _      1
# 564   P101_L_CM_CC         101    L  CESM   47                    _      1
#
#                             Findings View           Tags  Machine
# 556                  Non enhancement   CC  postoperative        1  \
# 557                  Non enhancement  MLO  postoperative        1
# 552  No mass or non mass enhancement   CC         normal        1
# 553  No mass or non mass enhancement  MLO         normal        1
# 564  No mass or non mass enhancement   CC         normal        1
#
#     classification
# 556         Benign
# 557         Benign
# 552         Normal
# 553         Normal
# 564         Normal

# %% [markdown]
# to access to manual file with name of image

# %%
#image_name =[]
#for i in range(len(filename_txt)):
    #image_name.append(filename_txt[i].replace('.jpg',''))

# %% [markdown]
# initialize size of validation_data and test_data

# %%
validation_data_size = int(len(loaded_images)*0.12)
test_data_size = int(len(loaded_images)*0.13)

# %%
random_select = np.random.choice(len(loaded_images), size=validation_data_size, replace=False)

# %% [markdown]
# set Validation data

# %%
validation_data_x = np.array(loaded_images)[random_select]
validation_data_y = manualRadio.iloc[random_select]
loaded_images = np.delete(loaded_images, random_select, axis=0)
manualRadio=manualRadio.drop(manualRadio.index[random_select])
# Out:
# C:\Users\shadmehr\AppData\Local\Temp\ipykernel_6084\3989429975.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   validation_data_x = np.array(loaded_images)[random_select]
# C:\Users\shadmehr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:5071: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asarray(arr)

# %%
validation_data_y.count()
# Out:
# Image_name              120
# Patient_ID              120
# Side                    120
# Type                    120
# Age                     120
# Breast density (ACR)    120
# BIRADS                  120
# Findings                120
# View                    120
# Tags                    120
# Machine                 120
# classification          120
# dtype: int64

# %%
random_select = np.random.choice(len(loaded_images), size=test_data_size, replace=False)

# %% [markdown]
# set test_data

# %%
test_data_x = np.array(loaded_images)[random_select]
test_data_y = manualRadio.iloc[random_select]
loaded_images = np.delete(loaded_images, random_select, axis=0)
manualRadio=manualRadio.drop(manualRadio.index[random_select])

# %%
test_data_y.count()
# Out:
# Image_name              130
# Patient_ID              130
# Side                    130
# Type                    130
# Age                     130
# Breast density (ACR)    130
# BIRADS                  130
# Findings                130
# View                    130
# Tags                    130
# Machine                 130
# classification          130
# dtype: int64

# %% [markdown]
# set train_data

# %%
train_data_x = np.array(loaded_images)
train_data_y = manualRadio[["Image_name" , "classification"]]

# %%
len(train_data_x)
# Out:
# 753

# %%
train_data_y.count()
# Out:
# Image_name        753
# classification    753
# dtype: int64

# %%
img = train_data_x[0]
plt.imshow(img)

# %%
train_data_y.head()
# Out:
#         Image_name classification
# 556   P100_L_CM_CC         Benign
# 557  P100_L_CM_MLO         Benign
# 564   P101_L_CM_CC         Normal
# 565  P101_L_CM_MLO         Normal
# 560   P101_R_CM_CC         Normal

# %% [markdown]
# Resize all images

# %%
import cv2

# %%
img1 = train_data_x[752]
plt.imshow(img1)

# %%
new_train_x = []

# %%
new_train_x = np.array([cv2.resize(i, (224, 224)) for i in train_data_x])

# %%
len(new_train_x)
# Out:
# 753

# %%
img = train_data_x[752]
img2 = cv2.resize(img,(224,224))
plt.imshow(img2)

# %%
train_data_x = new_train_x

# %%
img = train_data_x[752]
plt.imshow(img)

# %%
new_test_x = []
new_validation_x = []

# %%
new_test_x = np.array([cv2.resize(i, (224,224)) for i in test_data_x])
new_validation_x  = np.array([cv2.resize(i, (224, 224)) for i in validation_data_x])

# %%
test_data_x = new_test_x 
validation_data_x = new_validation_x

# %%
del new_train_x
del new_test_x 
del new_validation_x

# %%
import tensorflow as tf
import keras

# %% [markdown]
# Categorical lables

# %%
label_mapping = {'Benign': 0, 'Normal': 1, 'Malignant': 2}

# %%
integer_labels = train_data_y['classification'].map(label_mapping)

# %%
integer_labels_valid = validation_data_y['classification'].map(label_mapping)

# %%
y_train_to_categorical = keras.utils.to_categorical(integer_labels, num_classes=len(label_mapping), dtype='float32')

# %%
y_validation_to_categorical = keras.utils.to_categorical(integer_labels_valid, num_classes=len(label_mapping), dtype='float32')

# %% [markdown]
# Pre-trained Model ResNet152

# %% [markdown]
# Import neseccary libraries

# %%
from tensorflow.keras.applications.resnet import ResNet152 , preprocess_input , decode_predictions

# %% [markdown]
# Repeat grayscale channel three times to create pseudo RGB image

# %%
train_images_rgb = np.repeat(train_data_x[..., np.newaxis], 3, -1)[..., 0]
test_images_rgb = np.repeat(test_data_x[..., np.newaxis], 3, -1)
validation_images_rgb = np.repeat(validation_data_x[..., np.newaxis], 3, -1)[..., 0]

# %%
len(y_validation_to_categorical)
# Out:
# 120

# %% [markdown]
# Load pre_trained_model

# %%
#base_model = ResNet152(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %% [markdown]
# Load from file

# %%
base_model = tf.keras.models.load_model('../../resnet152.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# save into file

# %%
#base_model.save('../../resnet152.h5')

# %%
train_images_rgb = train_images_rgb/255
preprocess_images_test = preprocess_input(test_images_rgb)
validation_images_rgb = validation_images_rgb/255

# %% [markdown]
# ADD Layer

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D , Conv2D , Flatten
from keras import layers
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()

# %%
model.add(base_model)

# %%
for layer in base_model.layers[:150]:
    layer.trainable = False

# %%
for layer in base_model.layers[120:]:
    layer.trainable = True

# %%
#model.add(GlobalAveragePooling2D())

model.add(Conv2D(32 , kernel_size=(3,3) , activation = 'relu'))
model.add(Conv2D(64 , kernel_size=(3,3) , activation = 'relu'))
model.add(Flatten())
model.add(Dense(512 , activation = 'relu'))
model.add(layers.Dropout(0.3))
model.add(Dense(256 , activation='relu'))
model.add(layers.Dropout(0.2))
model.add(Dense(128 , activation='relu'))
model.add(layers.Dropout(0.2))
model.add(Dense(3,activation = 'softmax'))

# %% [markdown]
# freez base model

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
nemudar = model.fit(train_images_rgb, y_train_to_categorical,
                    validation_data=(validation_images_rgb, y_validation_to_categorical),
                    epochs=20)
# Out:
# Epoch 1/40
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 nemudar = model.fit(train_images_rgb, y_train_to_categorical,
#       2                     validation_data=(validation_images_rgb, y_validation_to_categorical),
#       3                     epochs=40)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\engine\training.py:1685, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1677 with tf.profiler.experimental.Trace(
#    1678     "train",
#    1679     epoch_num=epoch,
#    (...)
#    1682     _r=1,
#    1683 ):
#    1684     callbacks.on_train_batch_begin(step)
# -> 1685     tmp_logs = self.train_function(iterator)
#    1686     if data_handler.should_sync:
#    1687         context.async_wait()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:959, in Function._call(self, *args, **kwds)
#     955     pass  # Fall through to cond-based initialization.
#     956   else:
#     957     # Lifting succeeded, so variables are initialized and we can run the
#     958     # no_variable_creation function.
# --> 959     return self._no_variable_creation_fn(*args, **kwds)
#     960 else:
#     961   _, _, filtered_flat_args = (
#     962       self._variable_creation_fn._function_spec  # pylint: disable=protected-access
#     963       .canonicalize_function_inputs(
#     964           args, kwds))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# res1:After 18 epoch : i recognize after 12 epochs overfitting accured
